# %%
#pip install -q accelerate -U

# %% [markdown]
# ### ***Setup***

# %%
# !pip install transformers
# !pip install torch
# !pip install evaluate
# !pip install datasets
# Out:
# Requirement already satisfied: transformers in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (4.24.0)
# Requirement already satisfied: packaging>=20.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (0.11.0)
# Requirement already satisfied: filelock in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (3.8.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (1.23.3)
# Requirement already satisfied: tqdm>=4.27 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: torch in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (1.12.1)
# Requirement already satisfied: typing_extensions in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from torch) (4.3.0)
# Requirement already satisfied: evaluate in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: xxhash in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (3.1.0)
# Requirement already satisfied: requests>=2.19.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (1.23.3)
# Requirement already satisfied: dill in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: tqdm>=4.62.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (4.64.1)
# Requirement already satisfied: multiprocess in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (0.11.0)
# Requirement already satisfied: datasets>=2.0.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (2.7.0)
# Requirement already satisfied: pandas in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (1.4.4)
# Requirement already satisfied: packaging in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (21.3)
# Requirement already satisfied: responses<0.19 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (10.0.0)
# Requirement already satisfied: aiohttp in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: pytz>=2020.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from pandas->evaluate) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.1)
# Requirement already satisfied: six>=1.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Requirement already satisfied: datasets in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: numpy>=1.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (1.23.3)
# Requirement already satisfied: xxhash in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (3.1.0)
# Requirement already satisfied: packaging in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: dill<0.3.7 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: multiprocess in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: pyyaml>=5.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (10.0.0)
# Requirement already satisfied: pandas in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (1.4.4)
# Requirement already satisfied: aiohttp in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (2022.11.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (0.11.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (4.64.1)
# Requirement already satisfied: responses<0.19 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.3.0)
# Requirement already satisfied: filelock in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.11)
# Requirement already satisfied: pytz>=2020.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
import sklearn
import torch
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import evaluate
import gc
import numpy as np
from torch import nn
from transformers import Trainer
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
# Out:
# 2023-12-05 17:47:00.125809: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-05 17:47:02.928657: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-05 17:47:04.076516: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 17:47:19.226964: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-12-05 17:47:19.227932: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-12-05 17:47:19.227960: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline, AutoModel

checkpoint = 'seyonec/PubChem10M_SMILES_BPE_450k'
model = AutoModelForSequenceClassification.from_pretrained(checkpoint,num_labels=2).to(device)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Some weights of the model checkpoint at seyonec/PubChem10M_SMILES_BPE_450k were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at seyonec/PubChem10M_SMILES_BPE_450k and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### ***loading data***

# %%
train = pd.read_csv('train_data.txt', sep='\t')
train = train.rename(columns={'Smiles String': 'Smiles', 'agg' : 'label'})

test_agg = pd.read_csv('agg_data_test.txt', sep='\t')
test_agg['label']='AGG'
test_agg.drop('ID', axis=1, inplace = True)

test_non_agg= pd.read_csv('nonagg_data_test.txt', sep='\t')
test_non_agg['label']='NONAGG'
test_non_agg.drop('ID', axis=1, inplace = True)

data = pd.concat([test_agg, test_non_agg, train], ignore_index=True)

data = data.rename(columns={'label': 'labels','Smiles' : 'smiles' })

label_map = {
    'AGG': 1,
    'NONAGG': 0,
}

data = data.drop('Unnamed: 0', axis=1 )
data['labels'] = data['labels'].map(label_map)
data.dropna(inplace=True)

# %%
train_df, test_df = train_test_split(data, test_size=0.2, random_state = 42, stratify=data['labels'])
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state = 42,  stratify=train_df['labels'])

# %%
train_df['labels'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# Create a pipeline with both oversampling and undersampling steps
pipeline = Pipeline([
    ('over', RandomOverSampler(sampling_strategy=0.5)),  # Adjust sampling_strategy as needed
    ('under', RandomUnderSampler(sampling_strategy=1.0))  # Adjust sampling_strategy as needed
])

# Fit and apply the pipeline to the dataset
X_resampled, y_resampled = pipeline.fit_resample(train_df.drop('labels', axis=1), train_df['labels'])

# Combine the resampled features and labels into a new DataFrame
train_df = pd.DataFrame(X_resampled, columns=train_df.drop('labels', axis=1).columns)
train_df['labels'] = y_resampled

# %%
train_df['labels'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
from datasets import Dataset, DatasetDict

ds_dict = {'train' : Dataset.from_pandas(train_df),
           'valid' : Dataset.from_pandas(valid_df),
           'test' : Dataset.from_pandas(test_df)}

ds = DatasetDict(ds_dict)

# %%
def tokenize_function(examples):

    return tokenizer(examples["smiles"])#,truncation=True)

tokenized_datasets = ds.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_train=tokenized_datasets['train']
tokenized_valid=tokenized_datasets['valid']

# %%
from transformers import DataCollatorWithPadding

#Data collator that will dynamically pad the inputs received.
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)
    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred)
    geometric_mean = geometric_mean_score(y_true=labels, y_pred=pred)

    return {"accuracy": accuracy, "f1": f1, "geometric_mean": geometric_mean}

# %%
from collections import Counter

print(dict(Counter(tokenized_train['labels'])))
# Out:
# {0: 217, 1: 217}

# %% [markdown]
# ### ***Training***

# %%
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        labels = inputs.get("labels").to(device)
        inputs = {k: v.to(device) if isinstance(v, torch.Tensor) else v for k, v in inputs.items()}
        # forward pass
        outputs = model(**inputs)
        logits = outputs.get('logits')
        # compute custom loss
        loss_fct = nn.CrossEntropyLoss(weight=torch.tensor([0.5, 0.85]).to(device))
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# %%
from transformers import Trainer, TrainingArguments, EarlyStoppingCallback,  IntervalStrategy

training_args = TrainingArguments(output_dir="test_trainer", evaluation_strategy=IntervalStrategy.STEPS,
report_to="none", num_train_epochs=5, load_best_model_at_end=True, save_total_limit = 5,
metric_for_best_model = 'accuracy', eval_steps = 500, greater_is_better=True, learning_rate=2e-5,
lr_scheduler_type='linear')

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train ,
    eval_dataset=tokenized_valid,
    compute_metrics=compute_metrics,
    data_collator= data_collator,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.000085)]
)
# Out:
# PyTorch: setting up devices

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=275, training_loss=0.03428974498401988, metrics={'train_runtime': 8.8117, 'train_samples_per_second': 246.262, 'train_steps_per_second': 31.208, 'total_flos': 23972977001304.0, 'train_loss': 0.03428974498401988, 'epoch': 5.0})

# %% [markdown]
# ### ***Evaluation***

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test = tokenized_datasets["test"]
model_logits=trainer.predict(test)
pred_labels=model_logits.predictions.argmax(axis=1)

cm = confusion_matrix(test['labels'], pred_labels)
ConfusionMatrixDisplay(cm).plot()
# Out:
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: __index_level_0__, smiles. If __index_level_0__, smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8

# %%
precision_metric = evaluate.load("precision")
results = precision_metric.compute(references=test['labels'], predictions=pred_labels)

print(results)

recall_metric = evaluate.load("recall")
results = recall_metric.compute(references=test['labels'], predictions=pred_labels)

print(results)

f1_metric = evaluate.load("f1")
results = f1_metric.compute(references=test['labels'], predictions=pred_labels)

print(results)

acc_metric = evaluate.load("accuracy")
results = acc_metric.compute(references=test['labels'], predictions=pred_labels)

print(results)
# Out:
# {'precision': 0.5970149253731343}
# {'recall': 0.6896551724137931}
# {'f1': 0.64}
# {'accuracy': 0.7692307692307693}

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt


def roc_curve_plot(fpr,tpr,roc_auc):
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' %roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
logits_pt = torch.from_numpy(model_logits.predictions)
probabilities = nn.functional.softmax(logits_pt, dim=-1)
y_predict_prob= probabilities[:,1]

fpr, tpr, _ = roc_curve(test_df['labels'], y_predict_prob)
roc_auc = auc(fpr, tpr)
roc_curve_plot(fpr,tpr,roc_auc)

# %%
tn, fp, fn, tp = cm.ravel()

sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
ccr = (specificity+ sensitivity)/2
ppv = (tp / (tp + fp))
npv = (tn / (tn + fn)) if (tn + fn) > 0 else 0

# %%
print("sensitivity Results: {}".format(sensitivity))
print("specifity Results: {}".format(specificity))
print("ccr Results: {}".format(ccr))
print("npv Results: {}".format(npv))
print("ppv Results: {}".format(ppv))
# Out:
# sensitivity Results: 0.6896551724137931
# specifity Results: 0.8029197080291971
# ccr Results: 0.7462874402214952
# npv Results: 0.859375
# ppv Results: 0.5970149253731343

# %% [markdown]
# ## 10 runs

# %%
def runs(random_seed_list, data):

  ccr_list = []
  sen_list = []
  spe_list = []
  ppv_list = []
  npv_list = []
  auc_list = []
  i = 1

  for seed in random_seed_list:

        train_df1, test_df1 = train_test_split(data, test_size=0.2, random_state = seed, stratify=data['labels'])
        train_df1, valid_df1 = train_test_split(train_df1, test_size=0.2, random_state = seed,  stratify=train_df1['labels'])

        train_df1 = train_df1.reset_index(drop=True)
        valid_df1 = valid_df1.reset_index(drop=True)
        test_df1 = test_df1.reset_index(drop=True)

        # class balancing
        X_resampled, y_resampled = pipeline.fit_resample(train_df1.drop('labels', axis=1), train_df1['labels'])

        # Combine the resampled features and labels into a new DataFrame
        train_df1 = pd.DataFrame(X_resampled, columns=train_df1.drop('labels', axis=1).columns)
        train_df1['labels'] = y_resampled

        #datasets
        ds_dict = {'train' : Dataset.from_pandas(train_df1),
           'valid' : Dataset.from_pandas(valid_df1),
           'test' : Dataset.from_pandas(test_df1)}

        ds = DatasetDict(ds_dict)

        tokenized_datasets = ds.map(tokenize_function, batched=True)

        tokenized_train=tokenized_datasets['train']
        tokenized_valid=tokenized_datasets['valid']



        trainer = Trainer(
                            model=model,
                            args=training_args,
                            train_dataset=tokenized_train ,
                            eval_dataset=tokenized_valid,
                            compute_metrics=compute_metrics,
                            data_collator= data_collator,
                            callbacks=[EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.0001)]
                        )

        trainer.train()

        #evaluation
        test = tokenized_datasets["test"]
        model_logits=trainer.predict(test)
        pred_labels=model_logits.predictions.argmax(axis=1)

        cm = confusion_matrix(test['labels'], pred_labels)

        tn, fp, fn, tp = cm.ravel()

        sensitivity = tp / (tp + fn)
        specificity = tn / (tn + fp)
        ccr = (specificity+ sensitivity)/2
        ppv = (tp / (tp + fp))
        npv = (tn / (tn + fn))

        logits_pt = torch.from_numpy(model_logits.predictions)
        probabilities = nn.functional.softmax(logits_pt, dim=-1)
        y_predict_prob= probabilities[:,1]

        fpr, tpr, _ = roc_curve(test['labels'], y_predict_prob)
        roc_auc = auc(fpr, tpr)


        ccr_list.append(ccr)
        sen_list.append(sensitivity)
        spe_list.append(specificity)
        ppv_list.append(ppv)
        npv_list.append(npv)
        auc_list.append(roc_auc)

        print('finished run:', i)
        i = i+1

  return ccr_list, sen_list, spe_list, ppv_list, npv_list, auc_list

# %%
random_seed_list = [123, 80, 789, 567, 890, 345, 678, 901, 456, 12]

# %%
ccr_list, sen_list, spe_list, ppv_list, npv_list, auc_list = runs(random_seed_list, data)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 1
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:09, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 2
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 3
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 4
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 5
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 6
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 7
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 8
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 9
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/farah.alharthi/.conda/envs/ai701/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 434
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 275
#   Number of trainable parameters = 83450882
#     <div>
#
#       <progress value='275' max='275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [275/275 00:08, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: smiles. If smiles are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 195
#   Batch size = 8
# finished run: 10

# %%
# Calculate mean and standard deviation
ccr_mean = np.mean(ccr_list)
ccr_std = np.std(ccr_list)

sen_mean = np.mean(sen_list)
sen_std = np.std(sen_list)

spe_mean = np.mean(spe_list)
spe_std = np.std(spe_list)

ppv_mean = np.mean(ppv_list)
ppv_std = np.std(ppv_list)

npv_mean = np.mean(npv_list)
npv_std = np.std(npv_list)

auc_mean = np.mean(auc_list)
auc_std = np.std(auc_list)

# Print the results
print(f'Mean and Standard Deviation of CCR: {ccr_mean:.2f} ± {ccr_std:.2f}')
print(f'Mean and Standard Deviation of Sensitivity: {sen_mean:.2f} ± {sen_std:.2f}')
print(f'Mean and Standard Deviation of Specificity: {spe_mean:.2f} ± {spe_std:.2f}')
print(f'Mean and Standard Deviation of PPV: {ppv_mean:.2f} ± {ppv_std:.2f}')
print(f'Mean and Standard Deviation of NPV: {npv_mean:.2f} ± {npv_std:.2f}')
print(f'Mean and Standard Deviation of AUC: {auc_mean:.2f} ± {auc_std:.2f}')
# Out:
# Mean and Standard Deviation of CCR: 0.96 ± 0.04
# Mean and Standard Deviation of Sensitivity: 0.98 ± 0.03
# Mean and Standard Deviation of Specificity: 0.95 ± 0.04
# Mean and Standard Deviation of PPV: 0.90 ± 0.08
# Mean and Standard Deviation of NPV: 0.99 ± 0.01
# Mean and Standard Deviation of AUC: 0.99 ± 0.02
